# %%
import pandas as pd

# %%
df = pd.read_excel("feedback_results.xlsx")
df.head()
# Out:
#                                      retrievedChunks  \
# 0  ['{"system":" **Role:** You are the \\"TTKB Le...
# 1  ['Hangi daire başkanlıkları kurul başkan yardı...
# 2  ['{"system":" **Role:** You are the \\"TTKB Le...
# 3  ['{"system":" **Role:** You are the \\"TTKB Le...
# 4  ['{"system":" **Role:** You are the \\"TTKB Le...
#
#                               sessionId                             messageId  \
# 0  772bd8e8-66e0-4a40-82db-061a4eafa345  0315f430-803c-45af-b877-f63ee1b78cc5
# 1  772bd8e8-66e0-4a40-82db-061a4eafa345  2a68ece5-77f3-4cfc-8de2-137365db2cde
# 2  772bd8e8-66e0-4a40-82db-061a4eafa345  5509460f-ab2e-47fb-a231-9a44350a5773
# 3  772bd8e8-66e0-4a40-82db-061a4eafa345  77df51e9-2b41-4f98-9ca2-d902642a5c74
# 4  772bd8e8-66e0-4a40-82db-061a4eafa345  89f292a6-e8e9-474c-99cd-6ee9bbe63314
#
#                                   consultedDocuments  \
# 0  ['s3://goaltech-poc-ai-assistant/gold/mevzuat....
# 1  ['s3://goaltech-poc-ai-assistant/gold/09111225...
# ...

# %%
df.describe()
# Out:
#            point
# count  48.000000
# mean    7.229167
# std     3.799438
# min     0.000000
# 25%     5.000000
# 50%     9.000000
# 75%    10.000000
# max    10.000000
